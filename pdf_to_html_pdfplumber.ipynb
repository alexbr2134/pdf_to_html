# %%
from __future__ import annotations

import html
import time
import warnings
from pathlib import Path

import pdfplumber

warnings.filterwarnings("ignore")

ROOT = Path(".").resolve()
SAMPLES_DIR = ROOT / "парсинг pdf данные"
OUTPUT_DIR = ROOT / "парсинг html pdfplumber"

DOCUMENT_CSS = """
body { font-family: "Times New Roman", Times, serif; font-size: 11pt; line-height: 1.35; margin: 2em; }
table { border-collapse: collapse; margin: 0.6em 0 1em; width: auto; max-width: 100%; }
th, td { border: 1px solid #888; padding: 4px 10px; vertical-align: middle; text-align: left; }
td.num, th.num { text-align: right; }
h1, h2, h3, p { margin: 0.25em 0 0.5em; font-weight: inherit; font-size: inherit; }
.doc-section { margin-bottom: 0.75em; }
"""


def wrap_html_document(body: str, title: str = "Document") -> str:
    return (
        "<!DOCTYPE html>\n<html lang=\"ru\">\n<head>\n"
        f"<meta charset=\"utf-8\"><title>{html.escape(title)}</title>\n"
        f"<style>{DOCUMENT_CSS}</style>\n</head>\n<body>\n{body}\n</body>\n</html>"
    )


def cell_to_html(value) -> str:
    if value is None:
        return ""
    text = str(value).strip()
    if not text:
        return ""
    return html.escape(text).replace("\n", "<br>")


def raw_table_to_html(rows: list[list]) -> str:
    """Сырая сетка extract() → <table> без классификаций/span."""
    if not rows:
        return ""
    n_cols = max((len(r) for r in rows), default=0)
    lines = ["<table>"]
    for row in rows:
        padded = list(row) + [None] * (n_cols - len(row))
        lines.append("<tr>")
        for cell in padded:
            lines.append(f"<td>{cell_to_html(cell)}</td>")
        lines.append("</tr>")
    lines.append("</table>")
    return "\n".join(lines)


def _point_in_bbox(x: float, y: float, bbox, pad: float = 2.0) -> bool:
    x0, top, x1, bottom = bbox
    return (x0 - pad) <= x <= (x1 + pad) and (top - pad) <= y <= (bottom + pad)


def _words_outside_tables(page, table_bboxes: list[tuple]) -> list[dict]:
    words = page.extract_words(use_text_flow=True, keep_blank_chars=False) or []
    if not table_bboxes:
        return words
    out: list[dict] = []
    for w in words:
        cx = (w["x0"] + w["x1"]) / 2.0
        cy = (w["top"] + w["bottom"]) / 2.0
        if any(_point_in_bbox(cx, cy, b) for b in table_bboxes):
            continue
        out.append(w)
    return out


def _words_to_paragraph_html(words: list[dict], y_tol: float = 3.0) -> str:
    """Сырые слова → один <p> с <br> между строками (без умных заголовков)."""
    if not words:
        return ""
    ordered = sorted(words, key=lambda w: (round(w["top"], 1), w["x0"]))
    lines: list[list[str]] = []
    cur_top: float | None = None
    cur: list[str] = []
    for w in ordered:
        t = w["top"]
        text = (w.get("text") or "").strip()
        if not text:
            continue
        if cur_top is None or abs(t - cur_top) <= y_tol:
            cur.append(text)
            if cur_top is None:
                cur_top = t
        else:
            if cur:
                lines.append(cur)
            cur = [text]
            cur_top = t
    if cur:
        lines.append(cur)
    if not lines:
        return ""
    body = "<br>\n".join(html.escape(" ".join(line)) for line in lines)
    return f"<p>{body}</p>"


def _cluster_words_into_blocks(
    words: list[dict], gap: float = 14.0
) -> list[tuple[float, list[dict]]]:
    """Разбить слова вне таблиц на вертикальные блоки (для чередования с таблицами)."""
    if not words:
        return []
    ordered = sorted(words, key=lambda w: (w["top"], w["x0"]))
    blocks: list[list[dict]] = []
    cur: list[dict] = []
    prev_bottom: float | None = None
    for w in ordered:
        if prev_bottom is not None and (w["top"] - prev_bottom) > gap and cur:
            blocks.append(cur)
            cur = []
        cur.append(w)
        prev_bottom = max(prev_bottom or w["bottom"], w["bottom"])
    if cur:
        blocks.append(cur)
    return [(min(w["top"] for w in b), b) for b in blocks]


def build_page_body_pdfplumber(page) -> str:
    """Весь документ страницы: таблицы + текст вне них, сверху вниз."""
    found = page.find_tables()  # дефолтная стратегия lines
    table_sections: list[tuple[float, str]] = []
    table_bboxes: list[tuple] = []
    for table in found:
        bbox = tuple(table.bbox)
        table_bboxes.append(bbox)
        grid = table.extract()
        html_table = raw_table_to_html(grid or [])
        if html_table:
            table_sections.append(
                (bbox[1], f'<div class="doc-section">\n{html_table}\n</div>')
            )

    prose_words = _words_outside_tables(page, table_bboxes)
    prose_sections: list[tuple[float, str]] = []
    for top, block_words in _cluster_words_into_blocks(prose_words):
        p_html = _words_to_paragraph_html(block_words)
        if p_html:
            prose_sections.append((top, f'<div class="doc-section">{p_html}</div>'))

    if not table_sections and not prose_sections:
        text = (page.extract_text() or "").strip()
        if text:
            return (
                '<div class="doc-section"><p>'
                + html.escape(text).replace("\n", "<br>")
                + "</p></div>"
            )
        return ""

    merged = sorted(table_sections + prose_sections, key=lambda x: x[0])
    return "\n".join(html_part for _, html_part in merged)


def pdf_to_html_pdfplumber(pdf_path: str | Path) -> str:
    pdf_path = Path(pdf_path)
    sections: list[str] = []
    with pdfplumber.open(str(pdf_path)) as pdf:
        for pnum, page in enumerate(pdf.pages, start=1):
            body = build_page_body_pdfplumber(page)
            sections.append(f'<section class="page" data-page="{pnum}">\n{body}\n</section>')
    return wrap_html_document("\n".join(sections), title=pdf_path.stem)

# %% [markdown]
# ## Прогон всех PDF из `парсинг pdf данные`
#
# Результат → `парсинг html pdfplumber/`.
# Запускай ячейку ниже, когда будешь готов к экспорту (сам агент прогон не делал).

# %%
def export_parsing_pdfplumber(
    samples_dir: str | Path = SAMPLES_DIR,
    output_dir: str | Path = OUTPUT_DIR,
) -> dict:
    samples_dir = Path(samples_dir)
    output_dir = Path(output_dir)
    output_dir.mkdir(parents=True, exist_ok=True)

    pdfs = sorted(samples_dir.glob("*.pdf"))
    exported: list[str] = []
    total_pages = 0
    t0 = time.perf_counter()

    for pdf_path in pdfs:
        file_t0 = time.perf_counter()
        doc_html = pdf_to_html_pdfplumber(pdf_path)
        with pdfplumber.open(str(pdf_path)) as pdf:
            n_pages = len(pdf.pages)
        total_pages += n_pages
        out_path = output_dir / f"{pdf_path.stem}.html"
        out_path.write_text(doc_html, encoding="utf-8")
        exported.append(out_path.name)
        print(
            f"{pdf_path.name} -> {out_path.name} "
            f"({n_pages} стр., {time.perf_counter() - file_t0:.2f} с)",
            flush=True,
        )

    elapsed = time.perf_counter() - t0
    return {
        "pdf_count": len(pdfs),
        "total_pages": total_pages,
        "total_seconds": round(elapsed, 4),
        "exported_files": exported,
        "output_dir": str(output_dir),
    }


# Раскомментируй / запусти для полного прогона:
# stats = export_parsing_pdfplumber()
# print(stats)

# %%
stats = export_parsing_pdfplumber()
print(stats)
# Out:
# 1655388160-14.pdf -> 1655388160-14.html (1 стр., 1.09 с)
# 1655388160-26.pdf -> 1655388160-26.html (1 стр., 1.09 с)
# 1655388160-6.pdf -> 1655388160-6.html (1 стр., 3.02 с)
# 2508064833-12.pdf -> 2508064833-12.html (1 стр., 1.28 с)
# 2508064833-15.pdf -> 2508064833-15.html (1 стр., 1.45 с)
# 2508064833-17.pdf -> 2508064833-17.html (1 стр., 0.39 с)
# 2508064833-31.pdf -> 2508064833-31.html (1 стр., 1.49 с)
# 2703000015-111.pdf -> 2703000015-111.html (1 стр., 1.69 с)
# 2703000015-20.pdf -> 2703000015-20.html (1 стр., 0.69 с)
# 2703000015-24.pdf -> 2703000015-24.html (1 стр., 1.01 с)
# 2703000015-39.pdf -> 2703000015-39.html (1 стр., 0.56 с)
# 2703000015-46.pdf -> 2703000015-46.html (1 стр., 0.34 с)
# 2703000015-6.pdf -> 2703000015-6.html (1 стр., 0.50 с)
# 2703000015-9.pdf -> 2703000015-9.html (1 стр., 0.75 с)
# 2703000015-96.pdf -> 2703000015-96.html (1 стр., 1.29 с)
# chet_f.pdf -> chet_f.html (1 стр., 0.46 с)
# chet_f_2.pdf -> chet_f_2.html (1 стр., 0.94 с)
# ks3.pdf -> ks3.html (1 стр., 1.57 с)
# obrazec-schyota.pdf -> obrazec-schyota.html (1 стр., 0.79 с)
# sfv_2012.pdf -> sfv_2012.html (1 стр., 1.07 с)
# {'pdf_count': 20, 'total_pages': 20, 'total_seconds': 21.5563, 'exported_files': ['1655388160-14.html', '1655388160-26.html', '1655388160-6.html', '2508064833-12.html', '2508064833-15.html', '2508064833-17.html', '2508064833-31.html', '2703000015-111.html', '2703000015-20.html', '2703000015-24.html', '2703000015-39.html', '2703000015-46.html', '2703000015-6.html', '2703000015-9.html', '2703000015-96.html', 'chet_f.html', 'chet_f_2.html', 'ks3.html', 'obrazec-schyota.html', 'sfv_2012.html'], 'output_dir': '/Users/private/Desktop/pdf-to-html/парсинг html pdfplumber'}
